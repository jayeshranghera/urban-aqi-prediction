# %% [markdown]
# # 05 — Policy summary
#
# Indicative exceedance counts (hourly thresholds scaled by 24) for dashboard tables — not a substitute for legal compliance filings.
#
# **Output:** `data/processed/policy_summary.csv`

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "urban_aqi").is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from urban_aqi.paths import project_root
from urban_aqi.policy import write_policy_summary

df = write_policy_summary(project_root())
df
